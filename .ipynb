# %%
from paddleocr import PaddleOCR
import cv2
import numpy as np
# Also switch the language by modifying the lang parameter
ocr = PaddleOCR(lang="en") # The model file will be downloaded automatically when executed for the first time
img_path ='../bien-so-xe_0401085240.jpg'
result = ocr.ocr(img_path)
# Recognition and detection can be performed separately through parameter control
# result = ocr.ocr(img_path, det=False)  Only perform recognition
# result = ocr.ocr(img_path, rec=False)  Only perform detection
# Print detection frame and recognition result
for line in result:
    print(line)
 
# Visualization
mat = cv2.imread(img_path)
 
boxes = [line[0] for line in result[0]]
txts = [line[1][0] for line in result[0]]
scores = [line[1][1] for line in result[0]]
for box in boxes:
    pts = np.array(box,np.int32)
    pts = pts.reshape((-1, 1, 2))
    mat = cv2.polylines(
        img=mat,
        isClosed=True,
        pts=[pts],
        color = (255, 0, 0)
        )
# print(boxes)
cv2.imshow("result", mat)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import base64
import cv2
import os
img = cv2.imread("me.png")
def get_base64(img, name):
    cv2.imwrite(name+".png", img)
    converted_string = ""
    with open("me2.png", "rb") as image2string:
        converted_string = base64.b64encode(image2string.read())
    os.remove(name+".png")
    
    return str(converted_string.decode("utf-8")).replace("'","")
print(get_base64(img, "xxx"))
# Out:
# ...

# %%
import base64
  
  
with open("me.png", "rb") as image2string:
    converted_string = base64.b64encode(image2string.read())
print(converted_string)
  
with open('encode.bin', "wb") as file:
    file.write(converted_string)
# Out:
# b'...'

# %%
try:
    5-"ss"
except(TypeError, ZeroDivisionError):
    print("xxx")
# Out:
# xxx

# %%
x = [1,2,3]
print(x)
# Out:
# [1, 2, 3]

# %%
cv2.imshow("img",list_['img'])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for i in range(10):
    list_["num"] = 1

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

# %%
for x in car.keys():
    print(x)
# Out:
# brand
# model
# year

# %%
import cv2
import numpy as np
id = 'rtsp://30.0.0.20/1'
vid = cv2.VideoCapture(id)
while(vid.isOpened()):
    ret, frame = vid.read()
    print(frame.shape)
    if ret:
        cv2.imshow("frame", frame)
        cv2.waitKey(1)
    else:
        break
    print(frame.shape)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
cv2.destroyAllWindows()
vid.release()

# %%
char_list =  '0123456789ABCDEFGHKLMNPRSTUVXYZ'
txt = ["230","44F3"]
if(len(txt) == 2):
    out = ""
    for i in txt[0]:
        if(i in char_list):
            out += i 
    for j in txt[1]:
        if(j in char_list):
            out += j 
    print(out)
# Out:
# 23044F3

# %%
lst ={}
for i in range(10):
    lst["hello"]=0

# %%
import time
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

# %%
id_car = 0
print("SELECT top(1) State from action where id_car = {id_car}".format(id_car= id_car))
# Out:
# SELECT top(1) State from action where id_car = 0

# %%
def get_detect(mat):
    result = ocr.ocr(mat)
    
    boxes = [line[0] for line in result[0]]
    txt = [line[1][0] for line in result[0]]
    scores = [line[1][1] for line in result[0]]
    for box in boxes:
        pts = np.array(box,np.int32)
        pts = pts.reshape((-1, 1, 2))
        mat = cv2.polylines(
            img=mat,
            isClosed=True,
            pts=[pts],
            color = (255, 0, 0)
            )
    return mat,txt

# %%
mat = cv2.imread("./download.jpg")

# %%
from keras.models import model_from_json

# %%
img,txt = get_detect(mat)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3180/2535976132.py in <module>
# ----> 1 img,txt = get_detect(mat)
#
# ~\AppData\Local\Temp/ipykernel_3180/1689367192.py in get_detect(mat)
#       1 def get_detect(mat):
# ----> 2     result = ocr.ocr(mat)
#       3
#       4     boxes = [line[0] for line in result[0]]
#       5     txt = [line[1][0] for line in result[0]]
#
# c:\Users\ASUS\anaconda3\lib\site-packages\paddleocr\paddleocr.py in ocr(self, img, det, rec, cls)
#     512             cls: use angle classifier or not. Default is True. If true, the text with rotation of 180 degrees can be recognized. If no text is rotated by 180 degrees, use cls=False to get better performance. Text with rotation of 90 or 270 degrees can be recognized even if cls=False.
#     513         """
# --> 514         assert isinstance(img, (np.ndarray, list, str, bytes))
#     515         if isinstance(img, list) and det == True:
#     516             logger.error('When input a list of images, det must be false')
#
# AssertionError:

# %%
cv2.imshow("result", mat)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(txts)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3180/3734981381.py in <module>
# ----> 1 cv2.imshow("result", mat)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#       4 print(txts)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
pts = np.array([[25, 70], [25, 160],
                [110, 200], [200, 160],
                [200, 70], [110, 20]],
               np.int32)
 
pts = pts.reshape((-1, 1, 2))
print(pts)
# Out:
# [[[ 25  70]]
#
#  [[ 25 160]]
#
#  [[110 200]]
#
#  [[200 160]]
#
#  [[200  70]]
#
#  [[110  20]]]

# %%
for box in boxes:  
    print(box[0])
# Out:
# [[66.0, 2.0], [610.0, 0.0], [612.0, 241.0], [68.0, 245.0]]

# %%
for box in boxes:    
    top_left     = ((box[0][0][0]), (box[0][0][1]))
    bottom_right = ((box[2][0]), (box[2][1]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13244/50533028.py in <module>
#       1 for box in boxes:
#       2     top_left     = ((box[0][0][0]), (box[0][0][1]))
# ----> 3     bottom_right = ((box[2][0]), (box[2][1]))
#
# IndexError: list index out of range

# %%
x = []
for line in result[0]:
    x.append(line)
print(x)
# Out:
# [[[[66.0, 2.0], [610.0, 0.0], [612.0, 241.0], [68.0, 245.0]], ('99-H7', 0.9757689237594604)], [[[79.0, 232.0], [590.0, 237.0], [587.0, 454.0], [76.0, 453.0]], ('7060', 0.9987074136734009)]]

# %%
print(boxes)
print(txts)
print(scores)
# Out:
# [[[66.0, 2.0], [610.0, 0.0], [612.0, 241.0], [68.0, 245.0]], [[79.0, 232.0], [590.0, 237.0], [587.0, 454.0], [76.0, 453.0]]]
# ['99-H7', '7060']
# [0.9757689237594604, 0.9987074136734009]

# %%
for box in boxes:
    print(box)
    pts = np.array(box,
               np.int32)
    print(pts)
# Out:
# [[66.0, 2.0], [610.0, 0.0], [612.0, 241.0], [68.0, 245.0]]
# [[ 66   2]
#  [610   0]
#  [612 241]
#  [ 68 245]]
# [[79.0, 232.0], [590.0, 237.0], [587.0, 454.0], [76.0, 453.0]]
# [[ 79 232]
#  [590 237]
#  [587 454]
#  [ 76 453]]

# %%
x = 10

# %%
n = 5
i = 0
d = 0
c = 1
for i in range(0,n):
    print(d + c)
    f = d + c
    d = c
    c = f
# Out:
# 1
# 1
# 2
# 3
# 5

# %%
def save(filename, text):
    with open(filename, "w") as file:
        file.write(text)

    # Đóng file
    file.close()
save("t.txt","hello1")
